# %% [markdown]
# <a href="https://colab.research.google.com/github/ONGHuiYang/Python-Self-Learning/blob/main/Class%E8%AA%B2%E9%A1%8C%EF%BC%91.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 運転手クラスを定義する
class driver:

# クラス変数
	cost = 0

# コンストラクタ（必ず燃費を設定するようにする）
	def __init__(self, cost):
# （自分で書いてみましょう）
		self.cost = cost
# 燃費を取得するためのメソッド
	def getDrivingCost(self):
		return self.cost


# 車クラスを定義する
class car:

# クラス変数
	color = ""
	tank = ""
	gas = ""
	is_driver = False

# コンストラクタ
	def __init__(self, color, tank):
		self.color = color
		self.tank = tank

# 運転手を乗せるためのメソッド（返り値はなし）
	def getOn(self, driver):
		self.cost = driver.getDrivingCost()
		return 

# 運転手を下すためのメソッド（返り値はなし）
	def getDown(self):
		self.cost = ""
		return 

# 色を調べるためのメソッド
	def getColor(self):
		return self.color

# ガソリンの残量を調べるためのメソッド
	def getGas(self):
		return self.gas

	# ガソリンを入れるためのメソッド（返り値はなし）
	def setGas(self, gas):
# 現在の残ガソリン量と設定給油量がタンク容量を超えたら
		# 警告のメッセージを出力しつつ、満タンまでガソリンを車に入れる事とする。
		# 超えないならば、設定給油量をそのまま入れればよい。
		self.gas = gas
    if self.gas > self.tank :
      print("Your tank is over capacity. It is filled up. (" + str(self.tank) + " L)")
		return

	# 指定した距離だけドライブをする（返り値はなし）
	def drive(self, distance):
		# 運転手が乗っていない（＝""）場合、警告のメッセージを出して処理を終了。
		if self.cost == 0,
			print("No Driver in your car.")
		else:
			# 運転手が乗っているときは運転をする
			# 運転をすると距離÷燃費の分だけガソリンが減る。
			print(type(self.cost))
	    self.gas = self.gas - (dist/self.cost)
		  print(self.gas)
			# ガソリンが距離÷燃費よりも少ない場合、
			# 走った距離 dist を計算し、D のところでガソリンが空になった旨を
			# メッセージとして出力する。ガソリンが距離÷燃費よりも多ければ
			# そのまま走り切って終了とする
			# （自分で書いてみましょう）
			if self.gas < 0:
				self.gas = self.gas + (dist/self.cost)
				possible_dist = self.gas * self.cost
				print("After " + str(possible_dist) + " kilometers running, the tank will be empty.")
			else:
				print("Enough to run " + str(dist) + " kilometers.")
		return
# Out:
#   File "<ipython-input-22-fbe68390dd9a>", line 37
#     self.cost = ""
#                   ^
# IndentationError: unindent does not match any outer indentation level

# %%
# 実行してみる
A = driver(10)					# メッセージ出ない
car_of_A = car( "red", 50 )		# メッセージ出ない
print(car_of_A.getColor())		# red と出力される
car_of_A.getOn(A)				# メッセージ出ない
car_of_A.setGas(30)				# メッセージ出ない
car_of_A.drive(200)				# finish to run 200 kilometers.と出力される。
car_of_A.drive(300)				# After 100.0 kilometers running, the tank is empty.と出力される。
car_of_A.setGas(60)				# Your tank is over capacity. It is filled up.(50.0 L.) と出力される。
car_of_A.drive(600)				# finish to run 200 kilometers.と出力される。
car_of_A.getDown()				# メッセージ出ない

# %%
class driver:

	# クラス変数
	# （自分で書いてみましょう）
	cost = 0
	
	# コンストラクタ（必ず燃費を設定するようにする）
	def __init__(self, cost):
		# （自分で書いてみましょう）
		self.cost = cost
	# 燃費を取得するためのメソッド
	def getDrivingCost(self):
		return self.cost

class car:
 
	color = ""
	tank = ""
	gas = ""
	is_driver = False

  # コンストラクタ
	def __init__(self, color, tank):
		self.color = ""
		self.tank = tank
		self.cost = 0
		self.is_driver = False
 
	# 運転手を乗せるためのメソッド（返り値はなし）
	def getOn(self, driver):
		self.cost = driver.getDrivingCost()

	# 運転手を下すためのメソッド（返り値はなし）
	def getDown(self):
		# （自分で書いてみましょう）
		self.cost = 0

	# 色を調べるためのメソッド
	def getColor(self):
		return self.color 

	# ガソリンの残量を調べるためのメソッド
	def getGas(self):  
		return self.gas
	# ガソリンを入れるためのメソッド（返り値はなし）
	def setGas(self, gas):   
		self.gas = gas
		if(self.gas > self.tank):
			print("Your tank is over capacity. It is filled up.("+str(self.tank)+".0 L.)")
		# 現在の残ガソリン量と設定給油量がタンク容量を超えたら
		# 警告のメッセージを出力しつつ、満タンまでガソリンを車に入れる事とする。
		# 超えないならば、設定給油量をそのまま入れればよい。
		# （自分で書いてみましょう）
		return

	# 指定した距離だけドライブをする（返り値はなし）
	def drive(self, distance):
		# 運転手が乗っていない（＝""）場合、警告のメッセージを出して処理を終了。
		if (self.cost == 0): 
			print("No Driver in your car.")
		else:
			# 運転手が乗っているときは運転をする
 
			print(type(self.cost))
			self.gas = self.gas - (distance/self.cost) 
			print(self.gas)
			# 運転をすると距離÷燃費の分だけガソリンが減る。
			# （自分で書いてみましょう）
			# ガソリンが距離÷燃費よりも少ない場合、
			# 走った距離 dist を計算し、D のところでガソリンが空になった旨を
			# メッセージとして出力する。ガソリンが距離÷燃費よりも多ければ
			# そのまま走り切って終了とする
			# （自分で書いてみましょう）
			if (self.gas < 0):
				self.gas = self.gas + (distance/self.cost) 
				possible_distance = self.gas * self.cost
				print( "After "+str(possible_distance)+" kilometers running, the tank is empty")
			else:
				print("finish to run " +str(distance)+" kilometers")
